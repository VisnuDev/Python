# %%
1. What does RGBA stand for?
2. From the Pillow module, how do you get the RGBA value of any images?
3. What is a box tuple, and how does it work?
4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
6. After making changes to an Image object, how could you save it as an image file?
7. What module contains Pillow’s shape-drawing code?
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
1. What does RGBA stand for?

Ans:
    
    RGBA stands for Red-Green-Blue-Alpha

# %%
2. From the Pillow module, how do you get the RGBA value of any images?

Ans:
    using below code we can get RGBA values of an Image.
    
    
    Program:
        
        from PIL import Image, ImageColor
        img = Image.open(r"X:\Coding\Full stack data science ineuron\Python\Python basic assignment\SBI logo.png")
        rgba = img.convert("RGBA")
        datas = rgba.getdata()
        print(datas)

# %%
3. What is a box tuple, and how does it work?

#Ans:

A box tuple is a tuple value of four integers: 
    the left-edge x-coordinate, 
    the top-edge y-coordinate, 
    the width, and 
    the height,

# %%
4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

#Ans:

we can use Image_obj.size

# %%
from PIL import Image
img = Image.open('SBI logo.PNG')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=395x305 at 0x232BE4E8BB0>

# %%
print(img.size)
# Out:
# (395, 305)

# %%
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

#Ans:

we can use crop method. pFB

# %%
cropped_img= img.crop((0, 50, 50, 50))

# %%
6. After making changes to an Image object, how could you save it as an image file?

#Ans:

Call the img.save('newimg.png
                  ') method of the Image object.

# %%
img.crop((0, 50, 50, 50))
img.save('newimg.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=395x305 at 0x232BE4E8BB0>

# %%
7. What module contains Pillow’s shape-drawing code?

#Ans:

The ImageDraw module contains code to draw on images.

# %%
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

#Ans:

ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). 
They are returned by passing the Image object to the ImageDraw.Draw() function.
